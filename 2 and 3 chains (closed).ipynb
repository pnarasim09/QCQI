# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sym
from sympy import *
from sympy.matrices import Matrix

# %%
sx=np.matrix([[0,1],[1,0]])
sz=np.matrix([[1,0],[0,-1]])
ide=np.matrix([[1,0],[0,1]])

# %%
h2,g2,k2=sym.symbols('h2 g2 k2')
h3,g3,k3=sym.symbols('h3 g3 k3')

# %%
testM = sym.Matrix(h2*sz + g2*sx)
testM
# Out:
# Matrix([
# [h2,  g2],
# [g2, -h2]])

# %%
testM.eigenvals()
# Out:
# {-sqrt(g2**2 + h2**2): 1, sqrt(g2**2 + h2**2): 1}

# %%
Ham2=h2*(np.kron(sz,ide)+np.kron(ide,sz))+g2*(np.kron(sx,ide)+np.kron(ide,sx))-k2*(np.kron(sz,ide)*np.kron(ide,sz))

Ham2=Matrix(Ham2)
Ham2
# Out:
# Matrix([
# [2*h2 - k2, g2, g2,          0],
# [       g2, k2,  0,         g2],
# [       g2,  0, k2,         g2],
# [        0, g2, g2, -2*h2 - k2]])

# %%
hterm=h3*(np.kron(np.kron(sz,ide),ide)+np.kron(np.kron(ide,sz),ide)+np.kron(np.kron(ide,ide),sz))
gammaterm=g3*(np.kron(np.kron(sx,ide),ide)+np.kron(np.kron(ide,sx),ide)+np.kron(np.kron(ide,ide),sx))
jterm=k3*(
    np.kron(np.kron(sz,ide),ide)*np.kron(np.kron(ide,sz),ide)+
    np.kron(np.kron(ide,sz),ide)*np.kron(np.kron(ide,ide),sz)+
    np.kron(np.kron(sz,ide),ide)*np.kron(np.kron(ide,ide),sz)
)
Ham3=hterm+gammaterm-jterm

Ham3=Matrix(Ham3)
Ham3
# Out:
# Matrix([
# [3*h3 - 3*k3,      g3,      g3,        0,      g3,        0,        0,            0],
# [         g3, h3 + k3,       0,       g3,       0,       g3,        0,            0],
# [         g3,       0, h3 + k3,       g3,       0,        0,       g3,            0],
# [          0,      g3,      g3, -h3 + k3,       0,        0,        0,           g3],
# [         g3,       0,       0,        0, h3 + k3,       g3,       g3,            0],
# [          0,      g3,       0,        0,      g3, -h3 + k3,        0,           g3],
# [          0,       0,      g3,        0,      g3,        0, -h3 + k3,           g3],
# [          0,       0,       0,       g3,       0,       g3,       g3, -3*h3 - 3*k3]])

# %%
Ham3.col_swap(1,7)
Ham3
# Out:
# Matrix([
# [3*h3 - 3*k3,            0,      g3,        0,      g3,        0,        0,      g3],
# [         g3,            0,       0,       g3,       0,       g3,        0, h3 + k3],
# [         g3,            0, h3 + k3,       g3,       0,        0,       g3,       0],
# [          0,           g3,      g3, -h3 + k3,       0,        0,        0,      g3],
# [         g3,            0,       0,        0, h3 + k3,       g3,       g3,       0],
# [          0,           g3,       0,        0,      g3, -h3 + k3,        0,      g3],
# [          0,           g3,      g3,        0,      g3,        0, -h3 + k3,       0],
# [          0, -3*h3 - 3*k3,       0,       g3,       0,       g3,       g3,       0]])

# %%
Ham3.row_swap(1,7)
Ham3
# Out:
# Matrix([
# [3*h3 - 3*k3,            0,      g3,        0,      g3,        0,        0,      g3],
# [          0, -3*h3 - 3*k3,       0,       g3,       0,       g3,       g3,       0],
# [         g3,            0, h3 + k3,       g3,       0,        0,       g3,       0],
# [          0,           g3,      g3, -h3 + k3,       0,        0,        0,      g3],
# [         g3,            0,       0,        0, h3 + k3,       g3,       g3,       0],
# [          0,           g3,       0,        0,      g3, -h3 + k3,        0,      g3],
# [          0,           g3,      g3,        0,      g3,        0, -h3 + k3,       0],
# [         g3,            0,       0,       g3,       0,       g3,        0, h3 + k3]])

# %%
Ham3.col_swap(5,7)
Ham3
# Out:
# Matrix([
# [3*h3 - 3*k3,            0,      g3,        0,      g3,      g3,        0,        0],
# [          0, -3*h3 - 3*k3,       0,       g3,       0,       0,       g3,       g3],
# [         g3,            0, h3 + k3,       g3,       0,       0,       g3,        0],
# [          0,           g3,      g3, -h3 + k3,       0,      g3,        0,        0],
# [         g3,            0,       0,        0, h3 + k3,       0,       g3,       g3],
# [          0,           g3,       0,        0,      g3,      g3,        0, -h3 + k3],
# [          0,           g3,      g3,        0,      g3,       0, -h3 + k3,        0],
# [         g3,            0,       0,       g3,       0, h3 + k3,        0,       g3]])

# %%
Ham3.row_swap(5,7)
Ham3
# Out:
# Matrix([
# [3*h3 - 3*k3,            0,      g3,        0,      g3,      g3,        0,        0],
# [          0, -3*h3 - 3*k3,       0,       g3,       0,       0,       g3,       g3],
# [         g3,            0, h3 + k3,       g3,       0,       0,       g3,        0],
# [          0,           g3,      g3, -h3 + k3,       0,      g3,        0,        0],
# [         g3,            0,       0,        0, h3 + k3,       0,       g3,       g3],
# [         g3,            0,       0,       g3,       0, h3 + k3,        0,       g3],
# [          0,           g3,      g3,        0,      g3,       0, -h3 + k3,        0],
# [          0,           g3,       0,        0,      g3,      g3,        0, -h3 + k3]])

# %%
Ham3_hat=Ham3[:2,:2]
Ham3_hat
# Out:
# Matrix([
# [3*h3 - 3*k3,            0],
# [          0, -3*h3 - 3*k3]])

# %%
U3_hat=Ham3[2:,2:]
U3_hat
# Out:
# Matrix([
# [h3 + k3,       g3,       0,       0,       g3,        0],
# [     g3, -h3 + k3,       0,      g3,        0,        0],
# [      0,        0, h3 + k3,       0,       g3,       g3],
# [      0,       g3,       0, h3 + k3,        0,       g3],
# [     g3,        0,      g3,       0, -h3 + k3,        0],
# [      0,        0,      g3,      g3,        0, -h3 + k3]])

# %%
U3_hat_inv=U3_hat.inv()
U3_hat_inv
# Out:
# Matrix([
# [(3*g3**2*h3 - 3*g3**2*k3 + h3**3 - h3**2*k3 - h3*k3**2 + k3**3)/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4),                                  (2*g3**3 + g3*h3**2 - g3*k3**2)/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4),                                          (-g3**2*h3 + g3**2*k3)/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4),                                          (-g3**2*h3 + g3**2*k3)/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4),                                  (2*g3**3 + g3*h3**2 - g3*k3**2)/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4),                                                         -2*g3**3/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4)],
# [                                (2*g3**3 + g3*h3**2 - g3*k3**2)/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4), (-3*g3**2*h3 - 3*g3**2*k3 - h3**3 - h3**2*k3 + h3*k3**2 + k3**3)/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4),                                                        -2*g3**3/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4),                                 (2*g3**3 + g3*h3**2 - g3*k3**2)/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4),                                            (g3**2*h3 + g3**2*k3)/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4),                                            (g3**2*h3 + g3**2*k3)/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4)],
# [                                         (-g3**2*h3 + g3**2*k3)/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4),                                                         -2*g3**3/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4), (3*g3**2*h3 - 3*g3**2*k3 + h3**3 - h3**2*k3 - h3*k3**2 + k3**3)/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4),                                          (-g3**2*h3 + g3**2*k3)/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4),                                  (2*g3**3 + g3*h3**2 - g3*k3**2)/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4),                                  (2*g3**3 + g3*h3**2 - g3*k3**2)/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4)],
# [                                         (-g3**2*h3 + g3**2*k3)/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4),                                  (2*g3**3 + g3*h3**2 - g3*k3**2)/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4),                                          (-g3**2*h3 + g3**2*k3)/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4), (3*g3**2*h3 - 3*g3**2*k3 + h3**3 - h3**2*k3 - h3*k3**2 + k3**3)/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4),                                                         -2*g3**3/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4),                                  (2*g3**3 + g3*h3**2 - g3*k3**2)/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4)],
# [                                (2*g3**3 + g3*h3**2 - g3*k3**2)/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4),                                            (g3**2*h3 + g3**2*k3)/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4),                                 (2*g3**3 + g3*h3**2 - g3*k3**2)/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4),                                                        -2*g3**3/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4), (-3*g3**2*h3 - 3*g3**2*k3 - h3**3 - h3**2*k3 + h3*k3**2 + k3**3)/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4),                                            (g3**2*h3 + g3**2*k3)/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4)],
# [                                                       -2*g3**3/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4),                                            (g3**2*h3 + g3**2*k3)/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4),                                 (2*g3**3 + g3*h3**2 - g3*k3**2)/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4),                                 (2*g3**3 + g3*h3**2 - g3*k3**2)/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4),                                            (g3**2*h3 + g3**2*k3)/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4), (-3*g3**2*h3 - 3*g3**2*k3 - h3**3 - h3**2*k3 + h3*k3**2 + k3**3)/(4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4)]])

# %%
# a=(4*g3**4 + 5*g3**2*h3**2 - 4*g3**2*k3**2 + h3**4 - 4*h3**2*k3**2)
a=4*g3**4 + 5*g3**2*h3**2 - 5*g3**2*k3**2 + h3**4 - 2*h3**2*k3**2 + k3**4
new_U3_hat_inv=U3_hat_inv*a
new_U3_hat_inv
# Out:
# Matrix([
# [3*g3**2*h3 - 3*g3**2*k3 + h3**3 - h3**2*k3 - h3*k3**2 + k3**3,                                  2*g3**3 + g3*h3**2 - g3*k3**2,                                          -g3**2*h3 + g3**2*k3,                                          -g3**2*h3 + g3**2*k3,                                  2*g3**3 + g3*h3**2 - g3*k3**2,                                                       -2*g3**3],
# [                                2*g3**3 + g3*h3**2 - g3*k3**2, -3*g3**2*h3 - 3*g3**2*k3 - h3**3 - h3**2*k3 + h3*k3**2 + k3**3,                                                      -2*g3**3,                                 2*g3**3 + g3*h3**2 - g3*k3**2,                                            g3**2*h3 + g3**2*k3,                                            g3**2*h3 + g3**2*k3],
# [                                         -g3**2*h3 + g3**2*k3,                                                       -2*g3**3, 3*g3**2*h3 - 3*g3**2*k3 + h3**3 - h3**2*k3 - h3*k3**2 + k3**3,                                          -g3**2*h3 + g3**2*k3,                                  2*g3**3 + g3*h3**2 - g3*k3**2,                                  2*g3**3 + g3*h3**2 - g3*k3**2],
# [                                         -g3**2*h3 + g3**2*k3,                                  2*g3**3 + g3*h3**2 - g3*k3**2,                                          -g3**2*h3 + g3**2*k3, 3*g3**2*h3 - 3*g3**2*k3 + h3**3 - h3**2*k3 - h3*k3**2 + k3**3,                                                       -2*g3**3,                                  2*g3**3 + g3*h3**2 - g3*k3**2],
# [                                2*g3**3 + g3*h3**2 - g3*k3**2,                                            g3**2*h3 + g3**2*k3,                                 2*g3**3 + g3*h3**2 - g3*k3**2,                                                      -2*g3**3, -3*g3**2*h3 - 3*g3**2*k3 - h3**3 - h3**2*k3 + h3*k3**2 + k3**3,                                            g3**2*h3 + g3**2*k3],
# [                                                     -2*g3**3,                                            g3**2*h3 + g3**2*k3,                                 2*g3**3 + g3*h3**2 - g3*k3**2,                                 2*g3**3 + g3*h3**2 - g3*k3**2,                                            g3**2*h3 + g3**2*k3, -3*g3**2*h3 - 3*g3**2*k3 - h3**3 - h3**2*k3 + h3*k3**2 + k3**3]])

# %%
g3_hat=Ham3[2:,:2]
g3_hat
# Out:
# Matrix([
# [g3,  0],
# [ 0, g3],
# [g3,  0],
# [g3,  0],
# [ 0, g3],
# [ 0, g3]])

# %%
g3_hat.T
# Out:
# Matrix([
# [g3,  0, g3, g3,  0,  0],
# [ 0, g3,  0,  0, g3, g3]])

# %%
g3_hat.T*(U3_hat_inv*g3_hat).applyfunc(simplify)
# Out:
# Matrix([
# [3*g3**2*(h3 - k3)/(4*g3**2 + h3**2 - k3**2),            6*g3**3/(4*g3**2 + h3**2 - k3**2)],
# [          6*g3**3/(4*g3**2 + h3**2 - k3**2), -3*g3**2*(h3 + k3)/(4*g3**2 + h3**2 - k3**2)]])

# %%
Heff3_hat=Ham3_hat+g3_hat.T*(U3_hat_inv*g3_hat)
Heff3_hat=Heff3_hat.applyfunc(simplify)
Heff3_hat_new=Heff3_hat
Heff3_hat_new
# Out:
# Matrix([
# [3*(5*g3**2*h3 - 5*g3**2*k3 + h3**3 - h3**2*k3 - h3*k3**2 + k3**3)/(4*g3**2 + h3**2 - k3**2),                                                            6*g3**3/(4*g3**2 + h3**2 - k3**2)],
# [                                                          6*g3**3/(4*g3**2 + h3**2 - k3**2), 3*(-5*g3**2*h3 - 5*g3**2*k3 - h3**3 - h3**2*k3 + h3*k3**2 + k3**3)/(4*g3**2 + h3**2 - k3**2)]])

# %%
sym.simplify(Heff3_hat_new[0,0])
# Out:
# 3*(5*g3**2*h3 - 5*g3**2*k3 + h3**3 - h3**2*k3 - h3*k3**2 + k3**3)/(4*g3**2 + h3**2 - k3**2)

# %%
b=4*g3**2 + h3**2 - k3**2

# %%
heff3=3*(5*g3**2*h3 + h3**3 - h3*k3**2)/b
geff3=6*g3**3/b

heff2=2*h2
geff2=(2*g2**2)/k2

# %%
#when gamma3=0
h3_gam0=solve(heff3.subs(g3,0)-heff2,h3)[0]
h3_gam0
# Out:
# 2*h2/3 + k3

# %%
h2list=np.linspace(0.1,1,10)
h3list=[]
hefflist=[]
for h2val in h2list:
    h3list.append(h3_gam0.subs(h2,h2val))
    hefflist.append(2*h2val)
h2h3arr=np.array([h2list,h3list])
h2h3arr
# Out:
# array([[0.1, 0.2, 0.30000000000000004, 0.4, 0.5, 0.6, 0.7000000000000001,
#         0.8, 0.9, 1.0],
#        [k3 + 0.0666666666666667, k3 + 0.133333333333333, k3 + 0.2,
#         k3 + 0.266666666666667, k3 + 0.333333333333333, k3 + 0.4,
#         k3 + 0.466666666666667, k3 + 0.533333333333333, k3 + 0.6,
#         k3 + 0.666666666666667]], dtype=object)

# %%
#now we have a set of 10 ordered pairs (h2,h3) to work with

# %%
gammalist=np.linspace(0.1,2.0,20)
for j in range(len(gammalist)):
    gammaval=gammalist[j]
    print("gamma=",gammaval)
    
    for i in range(len(h2list)):
        h2val=h2list[i]
        h3val=h3list[i]
        print("h2=",h2val,"h3=",h3val)
        print("")

        heff2val=heff2.subs(h2,h2val)
        heff3val=heff3.subs([(h3,h3val),(g3,gammaval)])
        print("heff2=",heff2val)
        print("heff3=",heff3val.simplify())
        print("")

        geff2val=geff2.subs(g2,gammaval)
        geff3val=geff3.subs([(h3,h3val),(g3,gammaval)])
        print("geff2=",geff2val)
        print("geff3=",geff3val)
        print("")
        
        heffeq=solve(heff3val-heff2val,k3)
        print(heffeq)
        for sol in heffeq:
            if sol>0:
                k3sol=sol
        
                geff3val=geff3val.subs(k3,k3sol)
                geffeq=solve(geff2val-geff3val,k2)
                for sol in geffeq:
                    if sol>0:
                        k2sol=sol
        
                        print("")
                        print("h2=",h2val,"h3=",h3val)
                        print("k3=",k3sol)
                        print("k2=",k2sol)
                        print("")
                        print("")
# Out:
# gamma= 0.1
# h2= 0.1 h3= k3 + 0.0666666666666667
#
# heff2= 0.200000000000000
# heff3= (5.55111512312578e-17*k3**2 + 0.0266666666666667*k3 + 0.0108888888888889)/(0.133333333333333*k3 + 0.0444444444444444)
#
# geff2= 0.02/k2
# geff3= 0.006/(-k3**2 + (k3 + 0.0666666666666667)**2 + 0.04)
#
# []
# h2= 0.2 h3= k3 + 0.133333333333333
#
# heff2= 0.400000000000000
# heff3= (1.11022302462516e-16*k3**2 + 0.106666666666667*k3 + 0.0271111111111111)/(0.266666666666667*k3 + 0.0577777777777778)
#
# geff2= 0.02/k2
# geff3= 0.006/(-k3**2 + (k3 + 0.133333333333333)**2 + 0.04)
#
# []
# h2= 0.30000000000000004 h3= k3 + 0.2
#
# heff2= 0.600000000000000
# heff3= (0.24*k3 + 0.054)/(0.4*k3 + 0.08)
#
# geff2= 0.02/k2
# geff3= 0.006/(-k3**2 + (k3 + 0.2)**2 + 0.04)
#
# []
# h2= 0.4 h3= k3 + 0.266666666666667
#
# heff2= 0.800000000000000
# heff3= (2.22044604925031e-16*k3**2 + 0.426666666666667*k3 + 0.0968888888888889)/(0.533333333333333*k3 + 0.111111111111111)
#
# geff2= 0.02/k2
# geff3= 0.006/(-k3**2 + (k3 + 0.266666666666667)**2 + 0.04)
#
# []
# h2= 0.5 h3= k3 + 0.333333333333333
#
# heff2= 1.00000000000000
# heff3= (0.666666666666667*k3 + 0.161111111111111)/(0.666666666666667*k3 + 0.151111111111111)
#
# geff2= 0.02/k2
# geff3= 0.006/(-k3**2 + (k3 + 0.333333333333333)**2 + 0.04)
#
# []
# h2= 0.6 h3= k3 + 0.4
#
# heff2= 1.20000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 0.96*k3 + 0.252)/(0.8*k3 + 0.2)
#
# geff2= 0.02/k2
# geff3= 0.006/(-k3**2 + (k3 + 0.4)**2 + 0.04)
#
# []
# h2= 0.7000000000000001 h3= k3 + 0.466666666666667
#
# heff2= 1.40000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 1.30666666666667*k3 + 0.374888888888889)/(0.933333333333333*k3 + 0.257777777777778)
#
# geff2= 0.02/k2
# geff3= 0.006/(-k3**2 + (k3 + 0.466666666666667)**2 + 0.04)
#
# []
# h2= 0.8 h3= k3 + 0.533333333333333
#
# heff2= 1.60000000000000
# heff3= (4.44089209850063e-16*k3**2 + 1.70666666666667*k3 + 0.535111111111111)/(1.06666666666667*k3 + 0.324444444444444)
#
# geff2= 0.02/k2
# geff3= 0.006/(-k3**2 + (k3 + 0.533333333333333)**2 + 0.04)
#
# []
# h2= 0.9 h3= k3 + 0.6
#
# heff2= 1.80000000000000
# heff3= (2.16*k3 + 0.738)/(1.2*k3 + 0.4)
#
# geff2= 0.02/k2
# geff3= 0.006/(-k3**2 + (k3 + 0.6)**2 + 0.04)
#
# []
# h2= 1.0 h3= k3 + 0.666666666666667
#
# heff2= 2.00000000000000
# heff3= (2.66666666666667*k3 + 0.988888888888889)/(1.33333333333333*k3 + 0.484444444444444)
#
# geff2= 0.02/k2
# geff3= 0.006/(-k3**2 + (k3 + 0.666666666666667)**2 + 0.04)
#
# []
# gamma= 0.2
# h2= 0.1 h3= k3 + 0.0666666666666667
#
# heff2= 0.200000000000000
# heff3= (5.55111512312578e-17*k3**2 + 0.0266666666666667*k3 + 0.0408888888888889)/(0.133333333333333*k3 + 0.164444444444444)
#
# geff2= 0.08/k2
# geff3= 0.048/(-k3**2 + (k3 + 0.0666666666666667)**2 + 0.16)
#
# []
# h2= 0.2 h3= k3 + 0.133333333333333
#
# heff2= 0.400000000000000
# heff3= (1.11022302462516e-16*k3**2 + 0.106666666666667*k3 + 0.0871111111111111)/(0.266666666666667*k3 + 0.177777777777778)
#
# geff2= 0.08/k2
# geff3= 0.048/(-k3**2 + (k3 + 0.133333333333333)**2 + 0.16)
#
# []
# h2= 0.30000000000000004 h3= k3 + 0.2
#
# heff2= 0.600000000000000
# heff3= (0.24*k3 + 0.144)/(0.4*k3 + 0.2)
#
# geff2= 0.08/k2
# geff3= 0.048/(-k3**2 + (k3 + 0.2)**2 + 0.16)
#
# []
# h2= 0.4 h3= k3 + 0.266666666666667
#
# heff2= 0.800000000000000
# heff3= (2.22044604925031e-16*k3**2 + 0.426666666666667*k3 + 0.216888888888889)/(0.533333333333333*k3 + 0.231111111111111)
#
# geff2= 0.08/k2
# geff3= 0.048/(-k3**2 + (k3 + 0.266666666666667)**2 + 0.16)
#
# []
# h2= 0.5 h3= k3 + 0.333333333333333
#
# heff2= 1.00000000000000
# heff3= (0.666666666666667*k3 + 0.311111111111111)/(0.666666666666667*k3 + 0.271111111111111)
#
# geff2= 0.08/k2
# geff3= 0.048/(-k3**2 + (k3 + 0.333333333333333)**2 + 0.16)
#
# []
# h2= 0.6 h3= k3 + 0.4
#
# heff2= 1.20000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 0.96*k3 + 0.432)/(0.8*k3 + 0.32)
#
# geff2= 0.08/k2
# geff3= 0.048/(-k3**2 + (k3 + 0.4)**2 + 0.16)
#
# []
# h2= 0.7000000000000001 h3= k3 + 0.466666666666667
#
# heff2= 1.40000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 1.30666666666667*k3 + 0.584888888888889)/(0.933333333333333*k3 + 0.377777777777778)
#
# geff2= 0.08/k2
# geff3= 0.048/(-k3**2 + (k3 + 0.466666666666667)**2 + 0.16)
#
# []
# h2= 0.8 h3= k3 + 0.533333333333333
#
# heff2= 1.60000000000000
# heff3= (4.44089209850063e-16*k3**2 + 1.70666666666667*k3 + 0.775111111111111)/(1.06666666666667*k3 + 0.444444444444444)
#
# geff2= 0.08/k2
# geff3= 0.048/(-k3**2 + (k3 + 0.533333333333333)**2 + 0.16)
#
# []
# h2= 0.9 h3= k3 + 0.6
#
# heff2= 1.80000000000000
# heff3= (2.16*k3 + 1.008)/(1.2*k3 + 0.52)
#
# geff2= 0.08/k2
# geff3= 0.048/(-k3**2 + (k3 + 0.6)**2 + 0.16)
#
# []
# h2= 1.0 h3= k3 + 0.666666666666667
#
# heff2= 2.00000000000000
# heff3= (2.66666666666667*k3 + 1.28888888888889)/(1.33333333333333*k3 + 0.604444444444444)
#
# geff2= 0.08/k2
# geff3= 0.048/(-k3**2 + (k3 + 0.666666666666667)**2 + 0.16)
#
# []
# gamma= 0.3
# h2= 0.1 h3= k3 + 0.0666666666666667
#
# heff2= 0.200000000000000
# heff3= (5.55111512312578e-17*k3**2 + 0.0266666666666667*k3 + 0.0908888888888889)/(0.133333333333333*k3 + 0.364444444444444)
#
# geff2= 0.18/k2
# geff3= 0.162/(-k3**2 + (k3 + 0.0666666666666667)**2 + 0.36)
#
# []
# h2= 0.2 h3= k3 + 0.133333333333333
#
# heff2= 0.400000000000000
# heff3= (1.11022302462516e-16*k3**2 + 0.106666666666667*k3 + 0.187111111111111)/(0.266666666666667*k3 + 0.377777777777778)
#
# geff2= 0.18/k2
# geff3= 0.162/(-k3**2 + (k3 + 0.133333333333333)**2 + 0.36)
#
# []
# h2= 0.30000000000000004 h3= k3 + 0.2
#
# heff2= 0.600000000000000
# heff3= 2.5*(0.24*k3 + 0.294)/(k3 + 1)
#
# geff2= 0.18/k2
# geff3= 0.162/(-k3**2 + (k3 + 0.2)**2 + 0.36)
#
# []
# h2= 0.4 h3= k3 + 0.266666666666667
#
# heff2= 0.800000000000000
# heff3= (2.22044604925031e-16*k3**2 + 0.426666666666667*k3 + 0.416888888888889)/(0.533333333333333*k3 + 0.431111111111111)
#
# geff2= 0.18/k2
# geff3= 0.162/(-k3**2 + (k3 + 0.266666666666667)**2 + 0.36)
#
# []
# h2= 0.5 h3= k3 + 0.333333333333333
#
# heff2= 1.00000000000000
# heff3= (0.666666666666667*k3 + 0.561111111111111)/(0.666666666666667*k3 + 0.471111111111111)
#
# geff2= 0.18/k2
# geff3= 0.162/(-k3**2 + (k3 + 0.333333333333333)**2 + 0.36)
#
# []
# h2= 0.6 h3= k3 + 0.4
#
# heff2= 1.20000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 0.96*k3 + 0.732)/(0.8*k3 + 0.52)
#
# geff2= 0.18/k2
# geff3= 0.162/(-k3**2 + (k3 + 0.4)**2 + 0.36)
#
# []
# h2= 0.7000000000000001 h3= k3 + 0.466666666666667
#
# heff2= 1.40000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 1.30666666666667*k3 + 0.934888888888889)/(0.933333333333333*k3 + 0.577777777777778)
#
# geff2= 0.18/k2
# geff3= 0.162/(-k3**2 + (k3 + 0.466666666666667)**2 + 0.36)
#
# []
# h2= 0.8 h3= k3 + 0.533333333333333
#
# heff2= 1.60000000000000
# heff3= (4.44089209850063e-16*k3**2 + 1.70666666666667*k3 + 1.17511111111111)/(1.06666666666667*k3 + 0.644444444444444)
#
# geff2= 0.18/k2
# geff3= 0.162/(-k3**2 + (k3 + 0.533333333333333)**2 + 0.36)
#
# []
# h2= 0.9 h3= k3 + 0.6
#
# heff2= 1.80000000000000
# heff3= (2.16*k3 + 1.458)/(1.2*k3 + 0.72)
#
# geff2= 0.18/k2
# geff3= 0.162/(-k3**2 + (k3 + 0.6)**2 + 0.36)
#
# []
# h2= 1.0 h3= k3 + 0.666666666666667
#
# heff2= 2.00000000000000
# heff3= (2.66666666666667*k3 + 1.78888888888889)/(1.33333333333333*k3 + 0.804444444444444)
#
# geff2= 0.18/k2
# geff3= 0.162/(-k3**2 + (k3 + 0.666666666666667)**2 + 0.36)
#
# []
# gamma= 0.4
# h2= 0.1 h3= k3 + 0.0666666666666667
#
# heff2= 0.200000000000000
# heff3= (5.55111512312578e-17*k3**2 + 0.0266666666666667*k3 + 0.160888888888889)/(0.133333333333333*k3 + 0.644444444444444)
#
# geff2= 0.32/k2
# geff3= 0.384/(-k3**2 + (k3 + 0.0666666666666667)**2 + 0.64)
#
# []
# h2= 0.2 h3= k3 + 0.133333333333333
#
# heff2= 0.400000000000000
# heff3= (1.11022302462516e-16*k3**2 + 0.106666666666667*k3 + 0.327111111111111)/(0.266666666666667*k3 + 0.657777777777778)
#
# geff2= 0.32/k2
# geff3= 0.384/(-k3**2 + (k3 + 0.133333333333333)**2 + 0.64)
#
# []
# h2= 0.30000000000000004 h3= k3 + 0.2
#
# heff2= 0.600000000000000
# heff3= (0.24*k3 + 0.504)/(0.4*k3 + 0.68)
#
# geff2= 0.32/k2
# geff3= 0.384/(-k3**2 + (k3 + 0.2)**2 + 0.64)
#
# []
# h2= 0.4 h3= k3 + 0.266666666666667
#
# heff2= 0.800000000000000
# heff3= (2.22044604925031e-16*k3**2 + 0.426666666666667*k3 + 0.696888888888889)/(0.533333333333333*k3 + 0.711111111111111)
#
# geff2= 0.32/k2
# geff3= 0.384/(-k3**2 + (k3 + 0.266666666666667)**2 + 0.64)
#
# []
# h2= 0.5 h3= k3 + 0.333333333333333
#
# heff2= 1.00000000000000
# heff3= (0.666666666666667*k3 + 0.911111111111111)/(0.666666666666667*k3 + 0.751111111111111)
#
# geff2= 0.32/k2
# geff3= 0.384/(-k3**2 + (k3 + 0.333333333333333)**2 + 0.64)
#
# []
# h2= 0.6 h3= k3 + 0.4
#
# heff2= 1.20000000000000
# heff3= 1.25*(-4.44089209850063e-16*k3**2 + 0.96*k3 + 1.152)/(k3 + 1)
#
# geff2= 0.32/k2
# geff3= 0.384/(-k3**2 + (k3 + 0.4)**2 + 0.64)
#
# []
# h2= 0.7000000000000001 h3= k3 + 0.466666666666667
#
# heff2= 1.40000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 1.30666666666667*k3 + 1.42488888888889)/(0.933333333333333*k3 + 0.857777777777778)
#
# geff2= 0.32/k2
# geff3= 0.384/(-k3**2 + (k3 + 0.466666666666667)**2 + 0.64)
#
# []
# h2= 0.8 h3= k3 + 0.533333333333333
#
# heff2= 1.60000000000000
# heff3= (4.44089209850063e-16*k3**2 + 1.70666666666667*k3 + 1.73511111111111)/(1.06666666666667*k3 + 0.924444444444445)
#
# geff2= 0.32/k2
# geff3= 0.384/(-k3**2 + (k3 + 0.533333333333333)**2 + 0.64)
#
# []
# h2= 0.9 h3= k3 + 0.6
#
# heff2= 1.80000000000000
# heff3= (2.16*k3 + 2.088)/(1.2*k3 + 1.0)
#
# geff2= 0.32/k2
# geff3= 0.384/(-k3**2 + (k3 + 0.6)**2 + 0.64)
#
# []
# h2= 1.0 h3= k3 + 0.666666666666667
#
# heff2= 2.00000000000000
# heff3= (2.66666666666667*k3 + 2.48888888888889)/(1.33333333333333*k3 + 1.08444444444444)
#
# geff2= 0.32/k2
# geff3= 0.384/(-k3**2 + (k3 + 0.666666666666667)**2 + 0.64)
#
# []
# gamma= 0.5
# h2= 0.1 h3= k3 + 0.0666666666666667
#
# heff2= 0.200000000000000
# heff3= (5.55111512312578e-17*k3**2 + 0.0266666666666667*k3 + 0.250888888888889)/(0.133333333333333*k3 + 1.00444444444444)
#
# geff2= 0.5/k2
# geff3= 0.75/(-k3**2 + (k3 + 0.0666666666666667)**2 + 1.0)
#
# []
# h2= 0.2 h3= k3 + 0.133333333333333
#
# heff2= 0.400000000000000
# heff3= (1.11022302462516e-16*k3**2 + 0.106666666666667*k3 + 0.507111111111111)/(0.266666666666667*k3 + 1.01777777777778)
#
# geff2= 0.5/k2
# geff3= 0.75/(-k3**2 + (k3 + 0.133333333333333)**2 + 1.0)
#
# []
# h2= 0.30000000000000004 h3= k3 + 0.2
#
# heff2= 0.600000000000000
# heff3= (0.24*k3 + 0.774)/(0.4*k3 + 1.04)
#
# geff2= 0.5/k2
# geff3= 0.75/(-k3**2 + (k3 + 0.2)**2 + 1.0)
#
# []
# h2= 0.4 h3= k3 + 0.266666666666667
#
# heff2= 0.800000000000000
# heff3= (2.22044604925031e-16*k3**2 + 0.426666666666667*k3 + 1.05688888888889)/(0.533333333333333*k3 + 1.07111111111111)
#
# geff2= 0.5/k2
# geff3= 0.75/(-k3**2 + (k3 + 0.266666666666667)**2 + 1.0)
#
# []
# h2= 0.5 h3= k3 + 0.333333333333333
#
# heff2= 1.00000000000000
# heff3= (0.666666666666667*k3 + 1.36111111111111)/(0.666666666666667*k3 + 1.11111111111111)
#
# geff2= 0.5/k2
# geff3= 0.75/(-k3**2 + (k3 + 0.333333333333333)**2 + 1.0)
#
# []
# h2= 0.6 h3= k3 + 0.4
#
# heff2= 1.20000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 0.96*k3 + 1.692)/(0.8*k3 + 1.16)
#
# geff2= 0.5/k2
# geff3= 0.75/(-k3**2 + (k3 + 0.4)**2 + 1.0)
#
# []
# h2= 0.7000000000000001 h3= k3 + 0.466666666666667
#
# heff2= 1.40000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 1.30666666666667*k3 + 2.05488888888889)/(0.933333333333333*k3 + 1.21777777777778)
#
# geff2= 0.5/k2
# geff3= 0.75/(-k3**2 + (k3 + 0.466666666666667)**2 + 1.0)
#
# []
# h2= 0.8 h3= k3 + 0.533333333333333
#
# heff2= 1.60000000000000
# heff3= (4.44089209850063e-16*k3**2 + 1.70666666666667*k3 + 2.45511111111111)/(1.06666666666667*k3 + 1.28444444444444)
#
# geff2= 0.5/k2
# geff3= 0.75/(-k3**2 + (k3 + 0.533333333333333)**2 + 1.0)
#
# []
# h2= 0.9 h3= k3 + 0.6
#
# heff2= 1.80000000000000
# heff3= (2.16*k3 + 2.898)/(1.2*k3 + 1.36)
#
# geff2= 0.5/k2
# geff3= 0.75/(-k3**2 + (k3 + 0.6)**2 + 1.0)
#
# []
# h2= 1.0 h3= k3 + 0.666666666666667
#
# heff2= 2.00000000000000
# heff3= (2.66666666666667*k3 + 3.38888888888889)/(1.33333333333333*k3 + 1.44444444444444)
#
# geff2= 0.5/k2
# geff3= 0.75/(-k3**2 + (k3 + 0.666666666666667)**2 + 1.0)
#
# []
# gamma= 0.6
# h2= 0.1 h3= k3 + 0.0666666666666667
#
# heff2= 0.200000000000000
# heff3= (5.55111512312578e-17*k3**2 + 0.0266666666666667*k3 + 0.360888888888889)/(0.133333333333333*k3 + 1.44444444444444)
#
# geff2= 0.72/k2
# geff3= 1.296/(-k3**2 + (k3 + 0.0666666666666667)**2 + 1.44)
#
# []
# h2= 0.2 h3= k3 + 0.133333333333333
#
# heff2= 0.400000000000000
# heff3= (1.11022302462516e-16*k3**2 + 0.106666666666667*k3 + 0.727111111111111)/(0.266666666666667*k3 + 1.45777777777778)
#
# geff2= 0.72/k2
# geff3= 1.296/(-k3**2 + (k3 + 0.133333333333333)**2 + 1.44)
#
# []
# h2= 0.30000000000000004 h3= k3 + 0.2
#
# heff2= 0.600000000000000
# heff3= (0.24*k3 + 1.104)/(0.4*k3 + 1.48)
#
# geff2= 0.72/k2
# geff3= 1.296/(-k3**2 + (k3 + 0.2)**2 + 1.44)
#
# []
# h2= 0.4 h3= k3 + 0.266666666666667
#
# heff2= 0.800000000000000
# heff3= (2.22044604925031e-16*k3**2 + 0.426666666666667*k3 + 1.49688888888889)/(0.533333333333333*k3 + 1.51111111111111)
#
# geff2= 0.72/k2
# geff3= 1.296/(-k3**2 + (k3 + 0.266666666666667)**2 + 1.44)
#
# []
# h2= 0.5 h3= k3 + 0.333333333333333
#
# heff2= 1.00000000000000
# heff3= (0.666666666666667*k3 + 1.91111111111111)/(0.666666666666667*k3 + 1.55111111111111)
#
# geff2= 0.72/k2
# geff3= 1.296/(-k3**2 + (k3 + 0.333333333333333)**2 + 1.44)
#
# []
# h2= 0.6 h3= k3 + 0.4
#
# heff2= 1.20000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 0.96*k3 + 2.352)/(0.8*k3 + 1.6)
#
# geff2= 0.72/k2
# geff3= 1.296/(-k3**2 + (k3 + 0.4)**2 + 1.44)
#
# []
# h2= 0.7000000000000001 h3= k3 + 0.466666666666667
#
# heff2= 1.40000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 1.30666666666667*k3 + 2.82488888888889)/(0.933333333333333*k3 + 1.65777777777778)
#
# geff2= 0.72/k2
# geff3= 1.296/(-k3**2 + (k3 + 0.466666666666667)**2 + 1.44)
#
# []
# h2= 0.8 h3= k3 + 0.533333333333333
#
# heff2= 1.60000000000000
# heff3= (4.44089209850063e-16*k3**2 + 1.70666666666667*k3 + 3.33511111111111)/(1.06666666666667*k3 + 1.72444444444444)
#
# geff2= 0.72/k2
# geff3= 1.296/(-k3**2 + (k3 + 0.533333333333333)**2 + 1.44)
#
# []
# h2= 0.9 h3= k3 + 0.6
#
# heff2= 1.80000000000000
# heff3= (2.16*k3 + 3.888)/(1.2*k3 + 1.8)
#
# geff2= 0.72/k2
# geff3= 1.296/(-k3**2 + (k3 + 0.6)**2 + 1.44)
#
# []
# h2= 1.0 h3= k3 + 0.666666666666667
#
# heff2= 2.00000000000000
# heff3= (2.66666666666667*k3 + 4.48888888888889)/(1.33333333333333*k3 + 1.88444444444444)
#
# geff2= 0.72/k2
# geff3= 1.296/(-k3**2 + (k3 + 0.666666666666667)**2 + 1.44)
#
# []
# gamma= 0.7
# h2= 0.1 h3= k3 + 0.0666666666666667
#
# heff2= 0.200000000000000
# heff3= (5.55111512312578e-17*k3**2 + 0.0266666666666667*k3 + 0.490888888888889)/(0.133333333333333*k3 + 1.96444444444444)
#
# geff2= 0.98/k2
# geff3= 2.058/(-k3**2 + (k3 + 0.0666666666666667)**2 + 1.96)
#
# []
# h2= 0.2 h3= k3 + 0.133333333333333
#
# heff2= 0.400000000000000
# heff3= (1.11022302462516e-16*k3**2 + 0.106666666666667*k3 + 0.987111111111111)/(0.266666666666667*k3 + 1.97777777777778)
#
# geff2= 0.98/k2
# geff3= 2.058/(-k3**2 + (k3 + 0.133333333333333)**2 + 1.96)
#
# []
# h2= 0.30000000000000004 h3= k3 + 0.2
#
# heff2= 0.600000000000000
# heff3= (0.24*k3 + 1.494)/(0.4*k3 + 2.0)
#
# geff2= 0.98/k2
# geff3= 2.058/(-k3**2 + (k3 + 0.2)**2 + 1.96)
#
# []
# h2= 0.4 h3= k3 + 0.266666666666667
#
# heff2= 0.800000000000000
# heff3= (2.22044604925031e-16*k3**2 + 0.426666666666667*k3 + 2.01688888888889)/(0.533333333333333*k3 + 2.03111111111111)
#
# geff2= 0.98/k2
# geff3= 2.058/(-k3**2 + (k3 + 0.266666666666667)**2 + 1.96)
#
# []
# h2= 0.5 h3= k3 + 0.333333333333333
#
# heff2= 1.00000000000000
# heff3= (0.666666666666667*k3 + 2.56111111111111)/(0.666666666666667*k3 + 2.07111111111111)
#
# geff2= 0.98/k2
# geff3= 2.058/(-k3**2 + (k3 + 0.333333333333333)**2 + 1.96)
#
# []
# h2= 0.6 h3= k3 + 0.4
#
# heff2= 1.20000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 0.96*k3 + 3.132)/(0.8*k3 + 2.12)
#
# geff2= 0.98/k2
# geff3= 2.058/(-k3**2 + (k3 + 0.4)**2 + 1.96)
#
# []
# h2= 0.7000000000000001 h3= k3 + 0.466666666666667
#
# heff2= 1.40000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 1.30666666666667*k3 + 3.73488888888889)/(0.933333333333333*k3 + 2.17777777777778)
#
# geff2= 0.98/k2
# geff3= 2.058/(-k3**2 + (k3 + 0.466666666666667)**2 + 1.96)
#
# []
# h2= 0.8 h3= k3 + 0.533333333333333
#
# heff2= 1.60000000000000
# heff3= (4.44089209850063e-16*k3**2 + 1.70666666666667*k3 + 4.37511111111111)/(1.06666666666667*k3 + 2.24444444444444)
#
# geff2= 0.98/k2
# geff3= 2.058/(-k3**2 + (k3 + 0.533333333333333)**2 + 1.96)
#
# []
# h2= 0.9 h3= k3 + 0.6
#
# heff2= 1.80000000000000
# heff3= (2.16*k3 + 5.058)/(1.2*k3 + 2.32)
#
# geff2= 0.98/k2
# geff3= 2.058/(-k3**2 + (k3 + 0.6)**2 + 1.96)
#
# []
# h2= 1.0 h3= k3 + 0.666666666666667
#
# heff2= 2.00000000000000
# heff3= (2.66666666666667*k3 + 5.78888888888889)/(1.33333333333333*k3 + 2.40444444444444)
#
# geff2= 0.98/k2
# geff3= 2.058/(-k3**2 + (k3 + 0.666666666666667)**2 + 1.96)
#
# []
# gamma= 0.7999999999999999
# h2= 0.1 h3= k3 + 0.0666666666666667
#
# heff2= 0.200000000000000
# heff3= (5.55111512312578e-17*k3**2 + 0.0266666666666667*k3 + 0.640888888888889)/(0.133333333333333*k3 + 2.56444444444444)
#
# geff2= 1.28/k2
# geff3= 3.072/(-k3**2 + (k3 + 0.0666666666666667)**2 + 2.56)
#
# []
# h2= 0.2 h3= k3 + 0.133333333333333
#
# heff2= 0.400000000000000
# heff3= (1.11022302462516e-16*k3**2 + 0.106666666666667*k3 + 1.28711111111111)/(0.266666666666667*k3 + 2.57777777777778)
#
# geff2= 1.28/k2
# geff3= 3.072/(-k3**2 + (k3 + 0.133333333333333)**2 + 2.56)
# []
# h2= 0.30000000000000004 h3= k3 + 0.2
#
# heff2= 0.600000000000000
# heff3= (0.24*k3 + 1.944)/(0.4*k3 + 2.6)
#
# geff2= 1.28/k2
# geff3= 3.072/(-k3**2 + (k3 + 0.2)**2 + 2.56)
#
# []
# h2= 0.4 h3= k3 + 0.266666666666667
#
# heff2= 0.800000000000000
# heff3= (2.22044604925031e-16*k3**2 + 0.426666666666667*k3 + 2.61688888888889)/(0.533333333333333*k3 + 2.63111111111111)
#
# geff2= 1.28/k2
# geff3= 3.072/(-k3**2 + (k3 + 0.266666666666667)**2 + 2.56)
#
# []
# h2= 0.5 h3= k3 + 0.333333333333333
#
# heff2= 1.00000000000000
# heff3= (0.666666666666667*k3 + 3.31111111111111)/(0.666666666666667*k3 + 2.67111111111111)
#
# geff2= 1.28/k2
# geff3= 3.072/(-k3**2 + (k3 + 0.333333333333333)**2 + 2.56)
#
# []
# h2= 0.6 h3= k3 + 0.4
#
# heff2= 1.20000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 0.96*k3 + 4.032)/(0.8*k3 + 2.72)
#
# geff2= 1.28/k2
# geff3= 3.072/(-k3**2 + (k3 + 0.4)**2 + 2.56)
#
# []
# h2= 0.7000000000000001 h3= k3 + 0.466666666666667
#
# heff2= 1.40000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 1.30666666666667*k3 + 4.78488888888889)/(0.933333333333333*k3 + 2.77777777777778)
#
# geff2= 1.28/k2
# geff3= 3.072/(-k3**2 + (k3 + 0.466666666666667)**2 + 2.56)
#
# []
# h2= 0.8 h3= k3 + 0.533333333333333
#
# heff2= 1.60000000000000
# heff3= (4.44089209850063e-16*k3**2 + 1.70666666666667*k3 + 5.57511111111111)/(1.06666666666667*k3 + 2.84444444444444)
#
# geff2= 1.28/k2
# geff3= 3.072/(-k3**2 + (k3 + 0.533333333333333)**2 + 2.56)
#
# []
# h2= 0.9 h3= k3 + 0.6
#
# heff2= 1.80000000000000
# heff3= (2.16*k3 + 6.408)/(1.2*k3 + 2.92)
#
# geff2= 1.28/k2
# geff3= 3.072/(-k3**2 + (k3 + 0.6)**2 + 2.56)
#
# []
# h2= 1.0 h3= k3 + 0.666666666666667
#
# heff2= 2.00000000000000
# heff3= (2.66666666666667*k3 + 7.28888888888889)/(1.33333333333333*k3 + 3.00444444444444)
#
# geff2= 1.28/k2
# geff3= 3.072/(-k3**2 + (k3 + 0.666666666666667)**2 + 2.56)
#
# []
# gamma= 0.8999999999999999
# h2= 0.1 h3= k3 + 0.0666666666666667
#
# heff2= 0.200000000000000
# heff3= (5.55111512312578e-17*k3**2 + 0.0266666666666667*k3 + 0.810888888888889)/(0.133333333333333*k3 + 3.24444444444444)
#
# geff2= 1.62/k2
# geff3= 4.374/(-k3**2 + (k3 + 0.0666666666666667)**2 + 3.24)
#
# []
# h2= 0.2 h3= k3 + 0.133333333333333
#
# heff2= 0.400000000000000
# heff3= (1.11022302462516e-16*k3**2 + 0.106666666666667*k3 + 1.62711111111111)/(0.266666666666667*k3 + 3.25777777777778)
#
# geff2= 1.62/k2
# geff3= 4.374/(-k3**2 + (k3 + 0.133333333333333)**2 + 3.24)
#
# []
# h2= 0.30000000000000004 h3= k3 + 0.2
#
# heff2= 0.600000000000000
# heff3= (0.24*k3 + 2.454)/(0.4*k3 + 3.28)
#
# geff2= 1.62/k2
# geff3= 4.374/(-k3**2 + (k3 + 0.2)**2 + 3.24)
#
# []
# h2= 0.4 h3= k3 + 0.266666666666667
#
# heff2= 0.800000000000000
# heff3= (2.22044604925031e-16*k3**2 + 0.426666666666667*k3 + 3.29688888888889)/(0.533333333333333*k3 + 3.31111111111111)
#
# geff2= 1.62/k2
# geff3= 4.374/(-k3**2 + (k3 + 0.266666666666667)**2 + 3.24)
#
# []
# h2= 0.5 h3= k3 + 0.333333333333333
#
# heff2= 1.00000000000000
# heff3= (0.666666666666667*k3 + 4.16111111111111)/(0.666666666666667*k3 + 3.35111111111111)
#
# geff2= 1.62/k2
# geff3= 4.374/(-k3**2 + (k3 + 0.333333333333333)**2 + 3.24)
#
# []
# h2= 0.6 h3= k3 + 0.4
#
# heff2= 1.20000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 0.96*k3 + 5.052)/(0.8*k3 + 3.4)
#
# geff2= 1.62/k2
# geff3= 4.374/(-k3**2 + (k3 + 0.4)**2 + 3.24)
#
# []
# h2= 0.7000000000000001 h3= k3 + 0.466666666666667
#
# heff2= 1.40000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 1.30666666666667*k3 + 5.97488888888889)/(0.933333333333333*k3 + 3.45777777777778)
#
# geff2= 1.62/k2
# geff3= 4.374/(-k3**2 + (k3 + 0.466666666666667)**2 + 3.24)
#
# []
# h2= 0.8 h3= k3 + 0.533333333333333
#
# heff2= 1.60000000000000
# heff3= (4.44089209850063e-16*k3**2 + 1.70666666666667*k3 + 6.93511111111111)/(1.06666666666667*k3 + 3.52444444444444)
#
# geff2= 1.62/k2
# geff3= 4.374/(-k3**2 + (k3 + 0.533333333333333)**2 + 3.24)
#
# []
# h2= 0.9 h3= k3 + 0.6
#
# heff2= 1.80000000000000
# heff3= (2.16*k3 + 7.938)/(1.2*k3 + 3.6)
#
# geff2= 1.62/k2
# geff3= 4.374/(-k3**2 + (k3 + 0.6)**2 + 3.24)
#
# []
# h2= 1.0 h3= k3 + 0.666666666666667
#
# heff2= 2.00000000000000
# heff3= (2.66666666666667*k3 + 8.98888888888889)/(1.33333333333333*k3 + 3.68444444444444)
#
# geff2= 1.62/k2
# geff3= 4.374/(-k3**2 + (k3 + 0.666666666666667)**2 + 3.24)
#
# []
# gamma= 0.9999999999999999
# h2= 0.1 h3= k3 + 0.0666666666666667
#
# heff2= 0.200000000000000
# heff3= (5.55111512312578e-17*k3**2 + 0.0266666666666667*k3 + 1.00088888888889)/(0.133333333333333*k3 + 4.00444444444444)
#
# geff2= 2.0/k2
# geff3= 6.0/(-k3**2 + (k3 + 0.0666666666666667)**2 + 4.0)
#
# []
# h2= 0.2 h3= k3 + 0.133333333333333
#
# heff2= 0.400000000000000
# heff3= (1.11022302462516e-16*k3**2 + 0.106666666666667*k3 + 2.00711111111111)/(0.266666666666667*k3 + 4.01777777777778)
#
# geff2= 2.0/k2
# geff3= 6.0/(-k3**2 + (k3 + 0.133333333333333)**2 + 4.0)
#
# []
# h2= 0.30000000000000004 h3= k3 + 0.2
#
# heff2= 0.600000000000000
# heff3= (0.24*k3 + 3.024)/(0.4*k3 + 4.04)
#
# geff2= 2.0/k2
# geff3= 6.0/(-k3**2 + (k3 + 0.2)**2 + 4.0)
#
# []
# h2= 0.4 h3= k3 + 0.266666666666667
#
# heff2= 0.800000000000000
# heff3= (2.22044604925031e-16*k3**2 + 0.426666666666667*k3 + 4.05688888888889)/(0.533333333333333*k3 + 4.07111111111111)
#
# geff2= 2.0/k2
# geff3= 6.0/(-k3**2 + (k3 + 0.266666666666667)**2 + 4.0)
#
# []
# h2= 0.5 h3= k3 + 0.333333333333333
#
# heff2= 1.00000000000000
# heff3= (0.666666666666667*k3 + 5.11111111111111)/(0.666666666666667*k3 + 4.11111111111111)
#
# geff2= 2.0/k2
# geff3= 6.0/(-k3**2 + (k3 + 0.333333333333333)**2 + 4.0)
#
# []
# h2= 0.6 h3= k3 + 0.4
#
# heff2= 1.20000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 0.96*k3 + 6.192)/(0.8*k3 + 4.16)
#
# geff2= 2.0/k2
# geff3= 6.0/(-k3**2 + (k3 + 0.4)**2 + 4.0)
#
# []
# h2= 0.7000000000000001 h3= k3 + 0.466666666666667
#
# heff2= 1.40000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 1.30666666666667*k3 + 7.30488888888889)/(0.933333333333333*k3 + 4.21777777777778)
#
# geff2= 2.0/k2
# geff3= 6.0/(-k3**2 + (k3 + 0.466666666666667)**2 + 4.0)
#
# []
# h2= 0.8 h3= k3 + 0.533333333333333
#
# heff2= 1.60000000000000
# heff3= (4.44089209850063e-16*k3**2 + 1.70666666666667*k3 + 8.45511111111111)/(1.06666666666667*k3 + 4.28444444444444)
#
# geff2= 2.0/k2
# geff3= 6.0/(-k3**2 + (k3 + 0.533333333333333)**2 + 4.0)
#
# []
# h2= 0.9 h3= k3 + 0.6
#
# heff2= 1.80000000000000
# heff3= (2.16*k3 + 9.648)/(1.2*k3 + 4.36)
#
# geff2= 2.0/k2
# geff3= 6.0/(-k3**2 + (k3 + 0.6)**2 + 4.0)
#
# []
# h2= 1.0 h3= k3 + 0.666666666666667
#
# heff2= 2.00000000000000
# heff3= (2.66666666666667*k3 + 10.8888888888889)/(1.33333333333333*k3 + 4.44444444444444)
#
# geff2= 2.0/k2
# geff3= 6.0/(-k3**2 + (k3 + 0.666666666666667)**2 + 4.0)
#
# []
# gamma= 1.0999999999999999
# h2= 0.1 h3= k3 + 0.0666666666666667
#
# heff2= 0.200000000000000
# heff3= (5.55111512312578e-17*k3**2 + 0.0266666666666667*k3 + 1.21088888888889)/(0.133333333333333*k3 + 4.84444444444444)
#
# geff2= 2.42/k2
# geff3= 7.986/(-k3**2 + (k3 + 0.0666666666666667)**2 + 4.84)
#
# []
# h2= 0.2 h3= k3 + 0.133333333333333
#
# heff2= 0.400000000000000
# heff3= (1.11022302462516e-16*k3**2 + 0.106666666666667*k3 + 2.42711111111111)/(0.266666666666667*k3 + 4.85777777777778)
#
# geff2= 2.42/k2
# geff3= 7.986/(-k3**2 + (k3 + 0.133333333333333)**2 + 4.84)
#
# []
# h2= 0.30000000000000004 h3= k3 + 0.2
#
# heff2= 0.600000000000000
# heff3= (0.24*k3 + 3.654)/(0.4*k3 + 4.88)
#
# geff2= 2.42/k2
# geff3= 7.986/(-k3**2 + (k3 + 0.2)**2 + 4.84)
#
# []
# h2= 0.4 h3= k3 + 0.266666666666667
#
# heff2= 0.800000000000000
# heff3= (2.22044604925031e-16*k3**2 + 0.426666666666667*k3 + 4.89688888888889)/(0.533333333333333*k3 + 4.91111111111111)
#
# geff2= 2.42/k2
# geff3= 7.986/(-k3**2 + (k3 + 0.266666666666667)**2 + 4.84)
#
# []
# h2= 0.5 h3= k3 + 0.333333333333333
#
# heff2= 1.00000000000000
# heff3= (0.666666666666667*k3 + 6.16111111111111)/(0.666666666666667*k3 + 4.95111111111111)
#
# geff2= 2.42/k2
# geff3= 7.986/(-k3**2 + (k3 + 0.333333333333333)**2 + 4.84)
#
# []
# h2= 0.6 h3= k3 + 0.4
#
# heff2= 1.20000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 0.96*k3 + 7.452)/(0.8*k3 + 5.0)
#
# geff2= 2.42/k2
# geff3= 7.986/(-k3**2 + (k3 + 0.4)**2 + 4.84)
#
# []
# h2= 0.7000000000000001 h3= k3 + 0.466666666666667
#
# heff2= 1.40000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 1.30666666666667*k3 + 8.77488888888889)/(0.933333333333333*k3 + 5.05777777777778)
#
# geff2= 2.42/k2
# geff3= 7.986/(-k3**2 + (k3 + 0.466666666666667)**2 + 4.84)
#
# []
# h2= 0.8 h3= k3 + 0.533333333333333
#
# heff2= 1.60000000000000
# heff3= (4.44089209850063e-16*k3**2 + 1.70666666666667*k3 + 10.1351111111111)/(1.06666666666667*k3 + 5.12444444444444)
#
# geff2= 2.42/k2
# geff3= 7.986/(-k3**2 + (k3 + 0.533333333333333)**2 + 4.84)
#
# []
# h2= 0.9 h3= k3 + 0.6
#
# heff2= 1.80000000000000
# heff3= (2.16*k3 + 11.538)/(1.2*k3 + 5.2)
#
# geff2= 2.42/k2
# geff3= 7.986/(-k3**2 + (k3 + 0.6)**2 + 4.84)
# []
# h2= 1.0 h3= k3 + 0.666666666666667
#
# heff2= 2.00000000000000
# heff3= (2.66666666666667*k3 + 12.9888888888889)/(1.33333333333333*k3 + 5.28444444444444)
#
# geff2= 2.42/k2
# geff3= 7.986/(-k3**2 + (k3 + 0.666666666666667)**2 + 4.84)
#
# []
# gamma= 1.2
# h2= 0.1 h3= k3 + 0.0666666666666667
#
# heff2= 0.200000000000000
# heff3= (5.55111512312578e-17*k3**2 + 0.0266666666666667*k3 + 1.44088888888889)/(0.133333333333333*k3 + 5.76444444444444)
#
# geff2= 2.88/k2
# geff3= 10.368/(-k3**2 + (k3 + 0.0666666666666667)**2 + 5.76)
#
# []
# h2= 0.2 h3= k3 + 0.133333333333333
#
# heff2= 0.400000000000000
# heff3= (1.11022302462516e-16*k3**2 + 0.106666666666667*k3 + 2.88711111111111)/(0.266666666666667*k3 + 5.77777777777778)
#
# geff2= 2.88/k2
# geff3= 10.368/(-k3**2 + (k3 + 0.133333333333333)**2 + 5.76)
#
# []
# h2= 0.30000000000000004 h3= k3 + 0.2
#
# heff2= 0.600000000000000
# heff3= (0.24*k3 + 4.344)/(0.4*k3 + 5.8)
#
# geff2= 2.88/k2
# geff3= 10.368/(-k3**2 + (k3 + 0.2)**2 + 5.76)
#
# []
# h2= 0.4 h3= k3 + 0.266666666666667
#
# heff2= 0.800000000000000
# heff3= (2.22044604925031e-16*k3**2 + 0.426666666666667*k3 + 5.81688888888889)/(0.533333333333333*k3 + 5.83111111111111)
#
# geff2= 2.88/k2
# geff3= 10.368/(-k3**2 + (k3 + 0.266666666666667)**2 + 5.76)
#
# []
# h2= 0.5 h3= k3 + 0.333333333333333
#
# heff2= 1.00000000000000
# heff3= (0.666666666666667*k3 + 7.31111111111111)/(0.666666666666667*k3 + 5.87111111111111)
#
# geff2= 2.88/k2
# geff3= 10.368/(-k3**2 + (k3 + 0.333333333333333)**2 + 5.76)
#
# []
# h2= 0.6 h3= k3 + 0.4
#
# heff2= 1.20000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 0.96*k3 + 8.832)/(0.8*k3 + 5.92)
#
# geff2= 2.88/k2
# geff3= 10.368/(-k3**2 + (k3 + 0.4)**2 + 5.76)
#
# []
# h2= 0.7000000000000001 h3= k3 + 0.466666666666667
#
# heff2= 1.40000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 1.30666666666667*k3 + 10.3848888888889)/(0.933333333333333*k3 + 5.97777777777778)
#
# geff2= 2.88/k2
# geff3= 10.368/(-k3**2 + (k3 + 0.466666666666667)**2 + 5.76)
#
# []
# h2= 0.8 h3= k3 + 0.533333333333333
#
# heff2= 1.60000000000000
# heff3= (4.44089209850063e-16*k3**2 + 1.70666666666667*k3 + 11.9751111111111)/(1.06666666666667*k3 + 6.04444444444444)
#
# geff2= 2.88/k2
# geff3= 10.368/(-k3**2 + (k3 + 0.533333333333333)**2 + 5.76)
#
# []
# h2= 0.9 h3= k3 + 0.6
#
# heff2= 1.80000000000000
# heff3= (2.16*k3 + 13.608)/(1.2*k3 + 6.12)
#
# geff2= 2.88/k2
# geff3= 10.368/(-k3**2 + (k3 + 0.6)**2 + 5.76)
#
# []
# h2= 1.0 h3= k3 + 0.666666666666667
#
# heff2= 2.00000000000000
# heff3= (2.66666666666667*k3 + 15.2888888888889)/(1.33333333333333*k3 + 6.20444444444444)
#
# geff2= 2.88/k2
# geff3= 10.368/(-k3**2 + (k3 + 0.666666666666667)**2 + 5.76)
#
# []
# gamma= 1.3
# h2= 0.1 h3= k3 + 0.0666666666666667
#
# heff2= 0.200000000000000
# heff3= (5.55111512312578e-17*k3**2 + 0.0266666666666667*k3 + 1.69088888888889)/(0.133333333333333*k3 + 6.76444444444444)
#
# geff2= 3.38/k2
# geff3= 13.182/(-k3**2 + (k3 + 0.0666666666666667)**2 + 6.76)
#
# []
# h2= 0.2 h3= k3 + 0.133333333333333
#
# heff2= 0.400000000000000
# heff3= (1.11022302462516e-16*k3**2 + 0.106666666666667*k3 + 3.38711111111111)/(0.266666666666667*k3 + 6.77777777777778)
#
# geff2= 3.38/k2
# geff3= 13.182/(-k3**2 + (k3 + 0.133333333333333)**2 + 6.76)
#
# []
# h2= 0.30000000000000004 h3= k3 + 0.2
#
# heff2= 0.600000000000000
# heff3= (0.24*k3 + 5.094)/(0.4*k3 + 6.8)
#
# geff2= 3.38/k2
# geff3= 13.182/(-k3**2 + (k3 + 0.2)**2 + 6.76)
#
# []
# h2= 0.4 h3= k3 + 0.266666666666667
#
# heff2= 0.800000000000000
# heff3= (2.22044604925031e-16*k3**2 + 0.426666666666667*k3 + 6.81688888888889)/(0.533333333333333*k3 + 6.83111111111111)
#
# geff2= 3.38/k2
# geff3= 13.182/(-k3**2 + (k3 + 0.266666666666667)**2 + 6.76)
#
# []
# h2= 0.5 h3= k3 + 0.333333333333333
#
# heff2= 1.00000000000000
# heff3= (0.666666666666667*k3 + 8.56111111111111)/(0.666666666666667*k3 + 6.87111111111111)
#
# geff2= 3.38/k2
# geff3= 13.182/(-k3**2 + (k3 + 0.333333333333333)**2 + 6.76)
#
# []
# h2= 0.6 h3= k3 + 0.4
#
# heff2= 1.20000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 0.96*k3 + 10.332)/(0.8*k3 + 6.92)
#
# geff2= 3.38/k2
# geff3= 13.182/(-k3**2 + (k3 + 0.4)**2 + 6.76)
#
# []
# h2= 0.7000000000000001 h3= k3 + 0.466666666666667
#
# heff2= 1.40000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 1.30666666666667*k3 + 12.1348888888889)/(0.933333333333333*k3 + 6.97777777777778)
#
# geff2= 3.38/k2
# geff3= 13.182/(-k3**2 + (k3 + 0.466666666666667)**2 + 6.76)
#
# []
# h2= 0.8 h3= k3 + 0.533333333333333
#
# heff2= 1.60000000000000
# heff3= (4.44089209850063e-16*k3**2 + 1.70666666666667*k3 + 13.9751111111111)/(1.06666666666667*k3 + 7.04444444444445)
#
# geff2= 3.38/k2
# geff3= 13.182/(-k3**2 + (k3 + 0.533333333333333)**2 + 6.76)
#
# []
# h2= 0.9 h3= k3 + 0.6
#
# heff2= 1.80000000000000
# heff3= (2.16*k3 + 15.858)/(1.2*k3 + 7.12)
#
# geff2= 3.38/k2
# geff3= 13.182/(-k3**2 + (k3 + 0.6)**2 + 6.76)
#
# []
# h2= 1.0 h3= k3 + 0.666666666666667
#
# heff2= 2.00000000000000
# heff3= (2.66666666666667*k3 + 17.7888888888889)/(1.33333333333333*k3 + 7.20444444444445)
#
# geff2= 3.38/k2
# geff3= 13.182/(-k3**2 + (k3 + 0.666666666666667)**2 + 6.76)
#
# []
# gamma= 1.4
# h2= 0.1 h3= k3 + 0.0666666666666667
#
# heff2= 0.200000000000000
# heff3= (5.55111512312578e-17*k3**2 + 0.0266666666666667*k3 + 1.96088888888889)/(0.133333333333333*k3 + 7.84444444444444)
#
# geff2= 3.92/k2
# geff3= 16.464/(-k3**2 + (k3 + 0.0666666666666667)**2 + 7.84)
#
# []
# h2= 0.2 h3= k3 + 0.133333333333333
#
# heff2= 0.400000000000000
# heff3= (1.11022302462516e-16*k3**2 + 0.106666666666667*k3 + 3.92711111111111)/(0.266666666666667*k3 + 7.85777777777778)
#
# geff2= 3.92/k2
# geff3= 16.464/(-k3**2 + (k3 + 0.133333333333333)**2 + 7.84)
#
# []
# h2= 0.30000000000000004 h3= k3 + 0.2
#
# heff2= 0.600000000000000
# heff3= (0.24*k3 + 5.904)/(0.4*k3 + 7.88)
#
# geff2= 3.92/k2
# geff3= 16.464/(-k3**2 + (k3 + 0.2)**2 + 7.84)
#
# []
# h2= 0.4 h3= k3 + 0.266666666666667
#
# heff2= 0.800000000000000
# heff3= (2.22044604925031e-16*k3**2 + 0.426666666666667*k3 + 7.89688888888889)/(0.533333333333333*k3 + 7.91111111111111)
#
# geff2= 3.92/k2
# geff3= 16.464/(-k3**2 + (k3 + 0.266666666666667)**2 + 7.84)
#
# []
# h2= 0.5 h3= k3 + 0.333333333333333
#
# heff2= 1.00000000000000
# heff3= (0.666666666666667*k3 + 9.91111111111111)/(0.666666666666667*k3 + 7.95111111111111)
#
# geff2= 3.92/k2
# geff3= 16.464/(-k3**2 + (k3 + 0.333333333333333)**2 + 7.84)
#
# []
# h2= 0.6 h3= k3 + 0.4
#
# heff2= 1.20000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 0.96*k3 + 11.952)/(0.8*k3 + 8.0)
#
# geff2= 3.92/k2
# geff3= 16.464/(-k3**2 + (k3 + 0.4)**2 + 7.84)
#
# []
# h2= 0.7000000000000001 h3= k3 + 0.466666666666667
#
# heff2= 1.40000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 1.30666666666667*k3 + 14.0248888888889)/(0.933333333333333*k3 + 8.05777777777778)
#
# geff2= 3.92/k2
# geff3= 16.464/(-k3**2 + (k3 + 0.466666666666667)**2 + 7.84)
#
# []
# h2= 0.8 h3= k3 + 0.533333333333333
#
# heff2= 1.60000000000000
# heff3= (4.44089209850063e-16*k3**2 + 1.70666666666667*k3 + 16.1351111111111)/(1.06666666666667*k3 + 8.12444444444444)
#
# geff2= 3.92/k2
# geff3= 16.464/(-k3**2 + (k3 + 0.533333333333333)**2 + 7.84)
#
# []
# h2= 0.9 h3= k3 + 0.6
#
# heff2= 1.80000000000000
# heff3= (2.16*k3 + 18.288)/(1.2*k3 + 8.2)
#
# geff2= 3.92/k2
# geff3= 16.464/(-k3**2 + (k3 + 0.6)**2 + 7.84)
#
# []
# h2= 1.0 h3= k3 + 0.666666666666667
#
# heff2= 2.00000000000000
# heff3= (2.66666666666667*k3 + 20.4888888888889)/(1.33333333333333*k3 + 8.28444444444444)
#
# geff2= 3.92/k2
# geff3= 16.464/(-k3**2 + (k3 + 0.666666666666667)**2 + 7.84)
#
# []
# gamma= 1.5
# h2= 0.1 h3= k3 + 0.0666666666666667
#
# heff2= 0.200000000000000
# heff3= (5.55111512312578e-17*k3**2 + 0.0266666666666667*k3 + 2.25088888888889)/(0.133333333333333*k3 + 9.00444444444445)
#
# geff2= 4.5/k2
# geff3= 20.25/(-k3**2 + (k3 + 0.0666666666666667)**2 + 9.0)
#
# []
# h2= 0.2 h3= k3 + 0.133333333333333
#
# heff2= 0.400000000000000
# heff3= (1.11022302462516e-16*k3**2 + 0.106666666666667*k3 + 4.50711111111111)/(0.266666666666667*k3 + 9.01777777777778)
#
# geff2= 4.5/k2
# geff3= 20.25/(-k3**2 + (k3 + 0.133333333333333)**2 + 9.0)
#
# []
# h2= 0.30000000000000004 h3= k3 + 0.2
#
# heff2= 0.600000000000000
# heff3= (0.24*k3 + 6.774)/(0.4*k3 + 9.04)
#
# geff2= 4.5/k2
# geff3= 20.25/(-k3**2 + (k3 + 0.2)**2 + 9.0)
#
# []
# h2= 0.4 h3= k3 + 0.266666666666667
#
# heff2= 0.800000000000000
# heff3= (2.22044604925031e-16*k3**2 + 0.426666666666667*k3 + 9.05688888888889)/(0.533333333333333*k3 + 9.07111111111111)
#
# geff2= 4.5/k2
# geff3= 20.25/(-k3**2 + (k3 + 0.266666666666667)**2 + 9.0)
#
# []
# h2= 0.5 h3= k3 + 0.333333333333333
#
# heff2= 1.00000000000000
# heff3= (0.666666666666667*k3 + 11.3611111111111)/(0.666666666666667*k3 + 9.11111111111111)
#
# geff2= 4.5/k2
# geff3= 20.25/(-k3**2 + (k3 + 0.333333333333333)**2 + 9.0)
#
# []
# h2= 0.6 h3= k3 + 0.4
# heff2= 1.20000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 0.96*k3 + 13.692)/(0.8*k3 + 9.16)
#
# geff2= 4.5/k2
# geff3= 20.25/(-k3**2 + (k3 + 0.4)**2 + 9.0)
#
# []
# h2= 0.7000000000000001 h3= k3 + 0.466666666666667
#
# heff2= 1.40000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 1.30666666666667*k3 + 16.0548888888889)/(0.933333333333333*k3 + 9.21777777777778)
#
# geff2= 4.5/k2
# geff3= 20.25/(-k3**2 + (k3 + 0.466666666666667)**2 + 9.0)
#
# []
# h2= 0.8 h3= k3 + 0.533333333333333
#
# heff2= 1.60000000000000
# heff3= (4.44089209850063e-16*k3**2 + 1.70666666666667*k3 + 18.4551111111111)/(1.06666666666667*k3 + 9.28444444444444)
#
# geff2= 4.5/k2
# geff3= 20.25/(-k3**2 + (k3 + 0.533333333333333)**2 + 9.0)
#
# []
# h2= 0.9 h3= k3 + 0.6
#
# heff2= 1.80000000000000
# heff3= (2.16*k3 + 20.898)/(1.2*k3 + 9.36)
#
# geff2= 4.5/k2
# geff3= 20.25/(-k3**2 + (k3 + 0.6)**2 + 9.0)
#
# []
# h2= 1.0 h3= k3 + 0.666666666666667
#
# heff2= 2.00000000000000
# heff3= (2.66666666666667*k3 + 23.3888888888889)/(1.33333333333333*k3 + 9.44444444444444)
#
# geff2= 4.5/k2
# geff3= 20.25/(-k3**2 + (k3 + 0.666666666666667)**2 + 9.0)
#
# []
# gamma= 1.5999999999999999
# h2= 0.1 h3= k3 + 0.0666666666666667
#
# heff2= 0.200000000000000
# heff3= (5.55111512312578e-17*k3**2 + 0.0266666666666667*k3 + 2.56088888888889)/(0.133333333333333*k3 + 10.2444444444444)
#
# geff2= 5.12/k2
# geff3= 24.576/(-k3**2 + (k3 + 0.0666666666666667)**2 + 10.24)
#
# []
# h2= 0.2 h3= k3 + 0.133333333333333
#
# heff2= 0.400000000000000
# heff3= (1.11022302462516e-16*k3**2 + 0.106666666666667*k3 + 5.12711111111111)/(0.266666666666667*k3 + 10.2577777777778)
#
# geff2= 5.12/k2
# geff3= 24.576/(-k3**2 + (k3 + 0.133333333333333)**2 + 10.24)
#
# []
# h2= 0.30000000000000004 h3= k3 + 0.2
#
# heff2= 0.600000000000000
# heff3= (0.24*k3 + 7.704)/(0.4*k3 + 10.28)
#
# geff2= 5.12/k2
# geff3= 24.576/(-k3**2 + (k3 + 0.2)**2 + 10.24)
#
# []
# h2= 0.4 h3= k3 + 0.266666666666667
#
# heff2= 0.800000000000000
# heff3= (2.22044604925031e-16*k3**2 + 0.426666666666667*k3 + 10.2968888888889)/(0.533333333333333*k3 + 10.3111111111111)
#
# geff2= 5.12/k2
# geff3= 24.576/(-k3**2 + (k3 + 0.266666666666667)**2 + 10.24)
#
# []
# h2= 0.5 h3= k3 + 0.333333333333333
#
# heff2= 1.00000000000000
# heff3= (0.666666666666667*k3 + 12.9111111111111)/(0.666666666666667*k3 + 10.3511111111111)
#
# geff2= 5.12/k2
# geff3= 24.576/(-k3**2 + (k3 + 0.333333333333333)**2 + 10.24)
#
# []
# h2= 0.6 h3= k3 + 0.4
#
# heff2= 1.20000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 0.96*k3 + 15.552)/(0.8*k3 + 10.4)
#
# geff2= 5.12/k2
# geff3= 24.576/(-k3**2 + (k3 + 0.4)**2 + 10.24)
#
# []
# h2= 0.7000000000000001 h3= k3 + 0.466666666666667
#
# heff2= 1.40000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 1.30666666666667*k3 + 18.2248888888889)/(0.933333333333333*k3 + 10.4577777777778)
#
# geff2= 5.12/k2
# geff3= 24.576/(-k3**2 + (k3 + 0.466666666666667)**2 + 10.24)
#
# []
# h2= 0.8 h3= k3 + 0.533333333333333
#
# heff2= 1.60000000000000
# heff3= (4.44089209850063e-16*k3**2 + 1.70666666666667*k3 + 20.9351111111111)/(1.06666666666667*k3 + 10.5244444444444)
#
# geff2= 5.12/k2
# geff3= 24.576/(-k3**2 + (k3 + 0.533333333333333)**2 + 10.24)
#
# []
# h2= 0.9 h3= k3 + 0.6
#
# heff2= 1.80000000000000
# heff3= (2.16*k3 + 23.688)/(1.2*k3 + 10.6)
#
# geff2= 5.12/k2
# geff3= 24.576/(-k3**2 + (k3 + 0.6)**2 + 10.24)
#
# []
# h2= 1.0 h3= k3 + 0.666666666666667
#
# heff2= 2.00000000000000
# heff3= (2.66666666666667*k3 + 26.4888888888889)/(1.33333333333333*k3 + 10.6844444444444)
#
# geff2= 5.12/k2
# geff3= 24.576/(-k3**2 + (k3 + 0.666666666666667)**2 + 10.24)
#
# []
# gamma= 1.7
# h2= 0.1 h3= k3 + 0.0666666666666667
#
# heff2= 0.200000000000000
# heff3= (5.55111512312578e-17*k3**2 + 0.0266666666666667*k3 + 2.89088888888889)/(0.133333333333333*k3 + 11.5644444444444)
#
# geff2= 5.78/k2
# geff3= 29.478/(-k3**2 + (k3 + 0.0666666666666667)**2 + 11.56)
#
# []
# h2= 0.2 h3= k3 + 0.133333333333333
#
# heff2= 0.400000000000000
# heff3= (1.11022302462516e-16*k3**2 + 0.106666666666667*k3 + 5.78711111111111)/(0.266666666666667*k3 + 11.5777777777778)
#
# geff2= 5.78/k2
# geff3= 29.478/(-k3**2 + (k3 + 0.133333333333333)**2 + 11.56)
#
# []
# h2= 0.30000000000000004 h3= k3 + 0.2
#
# heff2= 0.600000000000000
# heff3= (0.24*k3 + 8.694)/(0.4*k3 + 11.6)
#
# geff2= 5.78/k2
# geff3= 29.478/(-k3**2 + (k3 + 0.2)**2 + 11.56)
#
# []
# h2= 0.4 h3= k3 + 0.266666666666667
#
# heff2= 0.800000000000000
# heff3= (2.22044604925031e-16*k3**2 + 0.426666666666667*k3 + 11.6168888888889)/(0.533333333333333*k3 + 11.6311111111111)
#
# geff2= 5.78/k2
# geff3= 29.478/(-k3**2 + (k3 + 0.266666666666667)**2 + 11.56)
#
# []
# h2= 0.5 h3= k3 + 0.333333333333333
#
# heff2= 1.00000000000000
# heff3= (0.666666666666667*k3 + 14.5611111111111)/(0.666666666666667*k3 + 11.6711111111111)
#
# geff2= 5.78/k2
# geff3= 29.478/(-k3**2 + (k3 + 0.333333333333333)**2 + 11.56)
#
# []
# h2= 0.6 h3= k3 + 0.4
#
# heff2= 1.20000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 0.96*k3 + 17.532)/(0.8*k3 + 11.72)
#
# geff2= 5.78/k2
# geff3= 29.478/(-k3**2 + (k3 + 0.4)**2 + 11.56)
#
# []
# h2= 0.7000000000000001 h3= k3 + 0.466666666666667
#
# heff2= 1.40000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 1.30666666666667*k3 + 20.5348888888889)/(0.933333333333333*k3 + 11.7777777777778)
#
# geff2= 5.78/k2
# geff3= 29.478/(-k3**2 + (k3 + 0.466666666666667)**2 + 11.56)
#
# []
# h2= 0.8 h3= k3 + 0.533333333333333
#
# heff2= 1.60000000000000
# heff3= (4.44089209850063e-16*k3**2 + 1.70666666666667*k3 + 23.5751111111111)/(1.06666666666667*k3 + 11.8444444444444)
#
# geff2= 5.78/k2
# geff3= 29.478/(-k3**2 + (k3 + 0.533333333333333)**2 + 11.56)
#
# []
# h2= 0.9 h3= k3 + 0.6
#
# heff2= 1.80000000000000
# heff3= (2.16*k3 + 26.658)/(1.2*k3 + 11.92)
#
# geff2= 5.78/k2
# geff3= 29.478/(-k3**2 + (k3 + 0.6)**2 + 11.56)
#
# []
# h2= 1.0 h3= k3 + 0.666666666666667
#
# heff2= 2.00000000000000
# heff3= (2.66666666666667*k3 + 29.7888888888889)/(1.33333333333333*k3 + 12.0044444444444)
#
# geff2= 5.78/k2
# geff3= 29.478/(-k3**2 + (k3 + 0.666666666666667)**2 + 11.56)
#
# []
# gamma= 1.8
# h2= 0.1 h3= k3 + 0.0666666666666667
#
# heff2= 0.200000000000000
# heff3= (5.55111512312578e-17*k3**2 + 0.0266666666666667*k3 + 3.24088888888889)/(0.133333333333333*k3 + 12.9644444444444)
#
# geff2= 6.48/k2
# geff3= 34.992/(-k3**2 + (k3 + 0.0666666666666667)**2 + 12.96)
#
# []
# h2= 0.2 h3= k3 + 0.133333333333333
#
# heff2= 0.400000000000000
# heff3= (1.11022302462516e-16*k3**2 + 0.106666666666667*k3 + 6.48711111111111)/(0.266666666666667*k3 + 12.9777777777778)
#
# geff2= 6.48/k2
# geff3= 34.992/(-k3**2 + (k3 + 0.133333333333333)**2 + 12.96)
#
# []
# h2= 0.30000000000000004 h3= k3 + 0.2
#
# heff2= 0.600000000000000
# heff3= (0.24*k3 + 9.744)/(0.4*k3 + 13.0)
#
# geff2= 6.48/k2
# geff3= 34.992/(-k3**2 + (k3 + 0.2)**2 + 12.96)
#
# []
# h2= 0.4 h3= k3 + 0.266666666666667
#
# heff2= 0.800000000000000
# heff3= (2.22044604925031e-16*k3**2 + 0.426666666666667*k3 + 13.0168888888889)/(0.533333333333333*k3 + 13.0311111111111)
#
# geff2= 6.48/k2
# geff3= 34.992/(-k3**2 + (k3 + 0.266666666666667)**2 + 12.96)
#
# []
# h2= 0.5 h3= k3 + 0.333333333333333
#
# heff2= 1.00000000000000
# heff3= (0.666666666666667*k3 + 16.3111111111111)/(0.666666666666667*k3 + 13.0711111111111)
#
# geff2= 6.48/k2
# geff3= 34.992/(-k3**2 + (k3 + 0.333333333333333)**2 + 12.96)
#
# []
# h2= 0.6 h3= k3 + 0.4
#
# heff2= 1.20000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 0.96*k3 + 19.632)/(0.8*k3 + 13.12)
#
# geff2= 6.48/k2
# geff3= 34.992/(-k3**2 + (k3 + 0.4)**2 + 12.96)
#
# []
# h2= 0.7000000000000001 h3= k3 + 0.466666666666667
#
# heff2= 1.40000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 1.30666666666667*k3 + 22.9848888888889)/(0.933333333333333*k3 + 13.1777777777778)
#
# geff2= 6.48/k2
# geff3= 34.992/(-k3**2 + (k3 + 0.466666666666667)**2 + 12.96)
#
# []
# h2= 0.8 h3= k3 + 0.533333333333333
#
# heff2= 1.60000000000000
# heff3= (4.44089209850063e-16*k3**2 + 1.70666666666667*k3 + 26.3751111111111)/(1.06666666666667*k3 + 13.2444444444444)
#
# geff2= 6.48/k2
# geff3= 34.992/(-k3**2 + (k3 + 0.533333333333333)**2 + 12.96)
#
# []
# h2= 0.9 h3= k3 + 0.6
#
# heff2= 1.80000000000000
# heff3= (2.16*k3 + 29.808)/(1.2*k3 + 13.32)
#
# geff2= 6.48/k2
# geff3= 34.992/(-k3**2 + (k3 + 0.6)**2 + 12.96)
#
# []
# h2= 1.0 h3= k3 + 0.666666666666667
#
# heff2= 2.00000000000000
# heff3= (2.66666666666667*k3 + 33.2888888888889)/(1.33333333333333*k3 + 13.4044444444444)
#
# geff2= 6.48/k2
# geff3= 34.992/(-k3**2 + (k3 + 0.666666666666667)**2 + 12.96)
#
# []
# gamma= 1.9
# h2= 0.1 h3= k3 + 0.0666666666666667
#
# heff2= 0.200000000000000
# heff3= (5.55111512312578e-17*k3**2 + 0.0266666666666667*k3 + 3.61088888888889)/(0.133333333333333*k3 + 14.4444444444444)
#
# geff2= 7.22/k2
# geff3= 41.154/(-k3**2 + (k3 + 0.0666666666666667)**2 + 14.44)
#
# []
# h2= 0.2 h3= k3 + 0.133333333333333
#
# heff2= 0.400000000000000
# heff3= (1.11022302462516e-16*k3**2 + 0.106666666666667*k3 + 7.22711111111111)/(0.266666666666667*k3 + 14.4577777777778)
#
# geff2= 7.22/k2
# geff3= 41.154/(-k3**2 + (k3 + 0.133333333333333)**2 + 14.44)
#
# []
# h2= 0.30000000000000004 h3= k3 + 0.2
#
# heff2= 0.600000000000000
# heff3= (0.24*k3 + 10.854)/(0.4*k3 + 14.48)
#
# geff2= 7.22/k2
# geff3= 41.154/(-k3**2 + (k3 + 0.2)**2 + 14.44)
#
# []
# h2= 0.4 h3= k3 + 0.266666666666667
#
# heff2= 0.800000000000000
# heff3= (2.22044604925031e-16*k3**2 + 0.426666666666667*k3 + 14.4968888888889)/(0.533333333333333*k3 + 14.5111111111111)
#
# geff2= 7.22/k2
# geff3= 41.154/(-k3**2 + (k3 + 0.266666666666667)**2 + 14.44)
#
# []
# h2= 0.5 h3= k3 + 0.333333333333333
#
# heff2= 1.00000000000000
# heff3= (0.666666666666667*k3 + 18.1611111111111)/(0.666666666666667*k3 + 14.5511111111111)
#
# geff2= 7.22/k2
# geff3= 41.154/(-k3**2 + (k3 + 0.333333333333333)**2 + 14.44)
#
# []
# h2= 0.6 h3= k3 + 0.4
#
# heff2= 1.20000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 0.96*k3 + 21.852)/(0.8*k3 + 14.6)
#
# geff2= 7.22/k2
# geff3= 41.154/(-k3**2 + (k3 + 0.4)**2 + 14.44)
#
# []
# h2= 0.7000000000000001 h3= k3 + 0.466666666666667
#
# heff2= 1.40000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 1.30666666666667*k3 + 25.5748888888889)/(0.933333333333333*k3 + 14.6577777777778)
#
# geff2= 7.22/k2
# geff3= 41.154/(-k3**2 + (k3 + 0.466666666666667)**2 + 14.44)
#
# []
# h2= 0.8 h3= k3 + 0.533333333333333
#
# heff2= 1.60000000000000
# heff3= (4.44089209850063e-16*k3**2 + 1.70666666666667*k3 + 29.3351111111111)/(1.06666666666667*k3 + 14.7244444444444)
#
# geff2= 7.22/k2
# geff3= 41.154/(-k3**2 + (k3 + 0.533333333333333)**2 + 14.44)
#
# []
# h2= 0.9 h3= k3 + 0.6
#
# heff2= 1.80000000000000
# heff3= (2.16*k3 + 33.138)/(1.2*k3 + 14.8)
#
# geff2= 7.22/k2
# geff3= 41.154/(-k3**2 + (k3 + 0.6)**2 + 14.44)
#
# []
# h2= 1.0 h3= k3 + 0.666666666666667
#
# heff2= 2.00000000000000
# heff3= (2.66666666666667*k3 + 36.9888888888889)/(1.33333333333333*k3 + 14.8844444444444)
#
# geff2= 7.22/k2
# geff3= 41.154/(-k3**2 + (k3 + 0.666666666666667)**2 + 14.44)
#
# []
# gamma= 2.0
# h2= 0.1 h3= k3 + 0.0666666666666667
#
# heff2= 0.200000000000000
# heff3= (5.55111512312578e-17*k3**2 + 0.0266666666666667*k3 + 4.00088888888889)/(0.133333333333333*k3 + 16.0044444444444)
#
# geff2= 8.0/k2
# geff3= 48.0/(-k3**2 + (k3 + 0.0666666666666667)**2 + 16.0)
#
# []
# h2= 0.2 h3= k3 + 0.133333333333333
#
# heff2= 0.400000000000000
# heff3= (1.11022302462516e-16*k3**2 + 0.106666666666667*k3 + 8.00711111111111)/(0.266666666666667*k3 + 16.0177777777778)
#
# geff2= 8.0/k2
# geff3= 48.0/(-k3**2 + (k3 + 0.133333333333333)**2 + 16.0)
#
# []
# h2= 0.30000000000000004 h3= k3 + 0.2
#
# heff2= 0.600000000000000
# heff3= (0.24*k3 + 12.024)/(0.4*k3 + 16.04)
#
# geff2= 8.0/k2
# geff3= 48.0/(-k3**2 + (k3 + 0.2)**2 + 16.0)
#
# []
# h2= 0.4 h3= k3 + 0.266666666666667
#
# heff2= 0.800000000000000
# heff3= (2.22044604925031e-16*k3**2 + 0.426666666666667*k3 + 16.0568888888889)/(0.533333333333333*k3 + 16.0711111111111)
#
# geff2= 8.0/k2
# geff3= 48.0/(-k3**2 + (k3 + 0.266666666666667)**2 + 16.0)
#
# []
# h2= 0.5 h3= k3 + 0.333333333333333
#
# heff2= 1.00000000000000
# heff3= (0.666666666666667*k3 + 20.1111111111111)/(0.666666666666667*k3 + 16.1111111111111)
#
# geff2= 8.0/k2
# geff3= 48.0/(-k3**2 + (k3 + 0.333333333333333)**2 + 16.0)
#
# []
# h2= 0.6 h3= k3 + 0.4
#
# heff2= 1.20000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 0.96*k3 + 24.192)/(0.8*k3 + 16.16)
#
# geff2= 8.0/k2
# geff3= 48.0/(-k3**2 + (k3 + 0.4)**2 + 16.0)
#
# []
# h2= 0.7000000000000001 h3= k3 + 0.466666666666667
#
# heff2= 1.40000000000000
# heff3= (-4.44089209850063e-16*k3**2 + 1.30666666666667*k3 + 28.3048888888889)/(0.933333333333333*k3 + 16.2177777777778)
#
# geff2= 8.0/k2
# geff3= 48.0/(-k3**2 + (k3 + 0.466666666666667)**2 + 16.0)
#
# []
# h2= 0.8 h3= k3 + 0.533333333333333
#
# heff2= 1.60000000000000
# heff3= (4.44089209850063e-16*k3**2 + 1.70666666666667*k3 + 32.4551111111111)/(1.06666666666667*k3 + 16.2844444444444)
#
# geff2= 8.0/k2
# geff3= 48.0/(-k3**2 + (k3 + 0.533333333333333)**2 + 16.0)
#
# []
# h2= 0.9 h3= k3 + 0.6
#
# heff2= 1.80000000000000
# heff3= (2.16*k3 + 36.648)/(1.2*k3 + 16.36)
#
# geff2= 8.0/k2
# geff3= 48.0/(-k3**2 + (k3 + 0.6)**2 + 16.0)
#
# []
# h2= 1.0 h3= k3 + 0.666666666666667
#
# heff2= 2.00000000000000
# heff3= (2.66666666666667*k3 + 40.8888888888889)/(1.33333333333333*k3 + 16.4444444444444)
#
# geff2= 8.0/k2
# geff3= 48.0/(-k3**2 + (k3 + 0.666666666666667)**2 + 16.0)
#
# []
